# %% [markdown]
# My solution for No. 6 Appending and NumPy.

# %%
import pandas as pd

df_red = pd.read_csv('winequality-red.csv', sep = ';')
df_red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df_red.shape
# Out:
# (1599, 12)

# %%
df_white = pd.read_csv('winequality-white.csv', sep = ';')
df_white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# 1      9.5        6
# 2     10.1        6
# ...

# %%
df_white.shape
# Out:
# (4898, 12)

# %%
pd.isnull(df_red['fixed acidity']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['volatile acidity']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['citric acid']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['residual sugar']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['chlorides']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['free sulfur dioxide']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['total sulfur dioxide']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['density']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['pH']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['sulphates']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['alcohol']).values.any()
# Out:
# False

# %%
pd.isnull(df_red['quality']).values.any()
# Out:
# False

# %%
df_white[df_white.duplicated(keep='first')]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.2             0.230         0.32            8.50      0.058
# 5               8.1             0.280         0.40            6.90      0.050
# 7               7.0             0.270         0.36           20.70      0.045
# 8               6.3             0.300         0.34            1.60      0.049
# 20              6.2             0.660         0.48            1.20      0.029
# 39              7.3             0.240         0.39           17.95      0.057
# 48              7.0             0.310         0.26            7.40      0.069
# 61              6.0             0.190         0.26           12.40      0.048
# 63              6.6             0.380         0.15            4.60      0.044
# 74              6.7             0.230         0.31            2.10      0.046
# 75              7.4             0.240         0.29           10.10      0.050
# ...

# %%
df_white.nunique()
# Out:
# fixed acidity            68
# volatile acidity        125
# citric acid              87
# residual sugar          310
# chlorides               160
# free sulfur dioxide     132
# total sulfur dioxide    251
# density                 890
# pH                      103
# sulphates                79
# alcohol                 103
# quality                   7
# dtype: int64

# %%
import numpy as np

df_red.mean()
# Out:
# fixed acidity            8.319637
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# quality                  5.636023
# dtype: float64
